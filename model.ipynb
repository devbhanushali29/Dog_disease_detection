# %%
pip install ultralytics
# Out:
# ...
#   Using cached opencv_python-4.11.0.86-cp37-abi3-macosx_13_0_arm64.whl.metadata (20 kB)
# ...
#   Using cached requests-2.32.3-py3-none-any.whl.metadata (4.6 kB)
# ...
#   Using cached charset_normalizer-3.4.1-cp312-cp312-macosx_10_13_universal2.whl.metadata (35 kB)
# ...
#   Using cached idna-3.10-py3-none-any.whl.metadata (10 kB)
# ...
#   Using cached certifi-2025.1.31-py3-none-any.whl.metadata (2.5 kB)
# ...
#   Using cached jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# ...
#   Using cached MarkupSafe-3.0.2-cp312-cp312-macosx_11_0_arm64.whl.metadata (4.0 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 978.8/978.8 kB 5.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 3.4 MB/s eta 0:00:00a 0:00:01
# Using cached opencv_python-4.11.0.86-cp37-abi3-macosx_13_0_arm64.whl (37.3 MB)
# ...
# Using cached requests-2.32.3-py3-none-any.whl (64 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 66.5/66.5 MB 3.7 MB/s eta 0:00:0000:0100:01
# ...

# %%
from ultralytics import YOLO

# Load a YOLOv8 model (you can use yolov8n.pt or yolov8s.pt for better accuracy)
model = YOLO('yolov8n.pt')

# Train the model using your data.yaml
model.train(data='/Users/be.like.dev/Downloads/FOS_dog_dissease/dataset1/data.yaml', epochs=25, imgsz=640)
